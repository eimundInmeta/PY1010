# %% [markdown]
# # Omregning fra c til f
# ## Author: EFB
# ### 2024 10 29
# <h4 Overskrift på nivå 4 /h4>

# %%
C = 100  # grader celsius
F = C*1.8 + 32  # grader fahrenheit
print("F = ",F)
# Out:
# F =  212.0

# %% [markdown]
# ![image.png](attachment:c631c3d0-4f45-4b4e-a15a-01ae5a520526.png)
